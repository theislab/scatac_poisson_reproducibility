# %%
import anndata as ad
import os
import scanpy as sc
import poisson_atac as patac
import pandas as pd

# %%
adata = patac.data.load_trapnell()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 720613 × 1050819
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'cell', 'sample_name', 'donor_id', 'day_of_pregnancy', 'sex', 'tissue', 'batch', 'total', 'total_deduplicated', 'total_deduplicated_peaks', 'total_deduplicated_tss', 'frip', 'frit', 'x_chrom_window_counts', 'y_chrom_window_counts', 'autosome_window_counts', 'blacklist_fraction', 'RNA_snn_res.0.3', 'seurat_clusters', 'nCount_peaks', 'nFeature_peaks', 'tissue_umap_1', 'tissue_umap_2', 'cell_type'
#     uns: 'cell_type_colors'
#     obsm: 'RNA', 'pca.l2.harmony', 'umap'

# %%
sc.pl.umap(adata, color = 'cell_type')

# %%
patac.pl.count_distribution(adata, figsize=(12, 5), limit=80)

# %%
patac.pl.proportions(adata, lower_limit=1, upper_limit=2)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 720613 × 1050819
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'cell', 'sample_name', 'donor_id', 'day_of_pregnancy', 'sex', 'tissue', 'batch', 'total', 'total_deduplicated', 'total_deduplicated_peaks', 'total_deduplicated_tss', 'frip', 'frit', 'x_chrom_window_counts', 'y_chrom_window_counts', 'autosome_window_counts', 'blacklist_fraction', 'RNA_snn_res.0.3', 'seurat_clusters', 'nCount_peaks', 'nFeature_peaks', 'tissue_umap_1', 'tissue_umap_2', 'cell_type'
#     uns: 'cell_type_colors'
#     obsm: 'RNA', 'pca.l2.harmony', 'umap'

# %%
import sc_sequence as ssc
import poisson_atac as patac

# %%
data_path = '/storage/groups/ml01/workspace/laura.martens/atac_poisson_data/data'
adata = patac.data.load_neurips(data_path=data_path, only_train=False, convert_counts = True)

# %%
adata.var_names
# Out:
# Index(['chr1-9776-10668', 'chr1-180726-181005', 'chr1-181117-181803',
#        'chr1-191133-192055', 'chr1-267562-268456', 'chr1-629497-630394',
#        'chr1-633515-634474', 'chr1-778276-779191', 'chr1-816868-817761',
#        'chr1-822804-823597',
#        ...
#        'GL000195.1-137376-138301', 'GL000219.1-39933-40839',
#        'GL000219.1-42172-43054', 'GL000219.1-44703-45584',
#        'GL000219.1-45726-46450', 'GL000219.1-90062-90937',
#        'GL000219.1-99257-100160', 'KI270726.1-27152-28034',
#        'KI270713.1-21434-22336', 'KI270713.1-29629-30491'],
#       dtype='object', length=116490)

# %%
ssc.data.get_bed_file(adata, path='/lustre/groups/ml01/workspace/laura.martens/sequence_model/benchmark/neurips/peaks_primiary_contigs.bed', primary_contigs=True)
# Out:
# saving bad_file to /lustre/groups/ml01/workspace/laura.martens/sequence_model/benchmark/neurips/peaks_primiary_contigs.bed
# saving complete
#        Chromosome      Start        End
# 0            chr1       9776      10668
# 1            chr1     180726     181005
# 2            chr1     181117     181803
# 3            chr1     191133     192055
# 4            chr1     267562     268456
# ...           ...        ...        ...
# 116463       chrX  156001265  156002117
# 116464       chrX  156029992  156030883
# 116465       chrY   11295162   11295942
# 116466       chrY   11333659   11334343
# 116467       chrY   56836454   56837350
#
# [116468 rows x 3 columns]

# %%
# %load_ext autoreload 
# %autoreload 2
