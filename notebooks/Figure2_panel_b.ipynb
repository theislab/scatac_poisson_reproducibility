# %%
# %load_ext autoreload
# %autoreload 2
import seml
import seaborn as sns
from poisson_atac.utils import model_type_map
import itertools
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from poisson_atac.utils import load_experiment

# %%
save_path = 'processed/scib/'

# %%
dataset_map = {'neurips': 'Neurips\nall batches', 'hematopoiesis': 'Satpathy\net al.'}

# %% [markdown]
# # Load results

# %%
def load_seml(seml_database):
    results = seml.get_results(seml_database, to_data_frame=True,  fields=["config", "config_hash", "result", "batch_id"])

    results['config.data.dataset'] = results['config.data.dataset'].map(dataset_map)
    results['config.setup.model_params.use_observed_lib_size'] = results['config.setup.model_params.use_observed_lib_size'].map({True: "True", False: "False", np.nan: ''})
    results['config.model.model_type'] = results['config.model.model_type'] + results['config.setup.model_params.use_observed_lib_size'].astype(str) 
    results["config.model.model_type"] = results["config.model.model_type"].map(model_type_map)

    return results

# %%
model_order = [model_type_map['poissonviTrue'], model_type_map['binaryviTrue'], model_type_map["peakvi"]]

# %%
seml_database = 'atac_to_atac'

# %%
results = load_seml(seml_database)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
#   0%|          | 0/70 [00:00<?, ?it/s]

# %%
results
# Out:
#     _id  batch_id                       config_hash  config.overwrite  \
# 0     2         1  88e513708fc67d6d1551475a95af51de                 2
# 1     4         1  5c4f7a50d51ff2949ca583b19418c2a7                 4
# 2     6         1  588f6d281aaf2e7986e8fdfb690ee006                 6
# 3     8         1  61d5908ec4acefc22c8689f123fd7472                 8
# 4    10         1  8b2b121f2f554efb85dc68d4695ac271                10
# ..  ...       ...                               ...               ...
# 65  150         7  7d0c985bf0d3e036c099607fe645c5fd               150
# 66  151         7  1e7d434cfe8f33baf580c4b2a8e44660               151
# 67  152         7  fe026a1c9516e469d0c52a061f64e75d               152
# 68  153         7  480530ae004cd105aef0cb031a22c1e3               153
# 69  154         7  738a3a8377cca712a9c133bff9a43b7c               154
#
#    config.db_collection                                  config.data.batch  \
# 0          atac_to_atac  [s1d1, s1d2, s1d3, s2d1, s2d5, s3d10, s3d3, s3...
# 1          atac_to_atac  [s1d1, s1d2, s1d3, s2d1, s2d5, s3d10, s3d3, s3...
# 2          atac_to_atac  [s1d1, s1d2, s1d3, s2d1, s2d5, s3d10, s3d3, s3...
# 3          atac_to_atac  [s1d1, s1d2, s1d3, s2d1, s2d5, s3d10, s3d3, s3...
# 4          atac_to_atac  [s1d1, s1d2, s1d3, s2d1, s2d5, s3d10, s3d3, s3...
# ..                  ...                                                ...
# 65         atac_to_atac                                               None
# 66         atac_to_atac                                               None
# 67         atac_to_atac                                               None
# 68         atac_to_atac                                               None
# 69         atac_to_atac                                               None
#
#      config.data.dataset                config.model.model_type  \
# 0   Neurips\nall batches  Poisson VAE\n(observed seq. coverage)
# 1   Neurips\nall batches  Poisson VAE\n(observed seq. coverage)
# 2   Neurips\nall batches  Poisson VAE\n(observed seq. coverage)
# 3   Neurips\nall batches  Poisson VAE\n(observed seq. coverage)
# 4   Neurips\nall batches  Poisson VAE\n(observed seq. coverage)
# ..                   ...                                    ...
# 65      Satpathy\net al.   Binary VAE\n(observed seq. coverage)
# 66      Satpathy\net al.   Binary VAE\n(observed seq. coverage)
# 67      Satpathy\net al.   Binary VAE\n(observed seq. coverage)
# 68      Satpathy\net al.   Binary VAE\n(observed seq. coverage)
# 69      Satpathy\net al.   Binary VAE\n(observed seq. coverage)
#
#     config.optimization.regularization.learning_rate  \
# 0                                             0.0001
# 1                                             0.0001
# 2                                             0.0001
# 3                                             0.0001
# 4                                             0.0001
# ..                                               ...
# 65                                            0.0001
# 66                                            0.0001
# 67                                            0.0001
# 68                                            0.0001
# 69                                            0.0001
#
#     config.optimization.regularization.weight_decay  ...  config.seed  \
# 0                                             0.001  ...    906691060
# 1                                             0.001  ...    906691060
# 2                                             0.001  ...    906691060
# 3                                             0.001  ...    906691060
# 4                                             0.001  ...    906691060
# ..                                              ...  ...          ...
# 65                                            0.001  ...    906691060
# 66                                            0.001  ...    906691060
# 67                                            0.001  ...    906691060
# 68                                            0.001  ...    906691060
# 69                                            0.001  ...    906691060
#
#                                     result.test_cells  \
# 0                             Model
# auroc         ...
# 1                             Model
# auroc         ...
# 2                             Model
# auroc         ...
# 3                             Model
# auroc         ...
# 4                             Model
# auroc         ...
# ..                                                ...
# 65                            Model
# auroc         ...
# 66                            Model
# auroc         ...
# 67                            Model
# auroc         ...
# 68                            Model
# auroc         ...
# 69                            Model
# auroc         ...
#
#                              result.test_cells_counts  \
# 0                        Model
# poisson_loss  12019...
# 1                       Model
# poisson_loss  12017....
# 2                        Model
# poisson_loss  12017...
# 3                        Model
# poisson_loss  12017...
# 4                        Model
# poisson_loss  12019...
# ..                                                ...
# 65                                               None
# 66                                               None
# 67                                               None
# 68                                               None
# 69                                               None
#
#                                      result.embedding  \
# 0                                     0
# NMI_cluste...
# 1                                     0
# NMI_cluste...
# 2                                     0
# NMI_cluste...
# 3                                     0
# NMI_cluste...
# 4                                     0
# NMI_cluste...
# ..                                                ...
# 65                                    0
# NMI_cluste...
# 66                                    0
# NMI_cluste...
# 67                                    0
# NMI_cluste...
# 68                                    0
# NMI_cluste...
# 69                                    0
# NMI_cluste...
#
#     result.average_precision result.rmse    result.bce result.nmi result.ari  \
# 0                   0.269281    0.154149  10813.440339   0.746448   0.671021
# 1                   0.269407    0.154142  10811.580137   0.759786   0.707106
# 2                   0.269365    0.154143  10812.183573   0.747384   0.689954
# 3                   0.269371    0.154142  10812.071546   0.752737   0.699916
# 4                   0.269377    0.154143  10813.581549   0.748841   0.704337
# ..                       ...         ...           ...        ...        ...
# 65                  0.255357    0.182014  17160.755166   0.820092   0.702478
# 66                  0.259412    0.184366  17544.621165   0.819284   0.711446
# 67                  0.256632    0.183881  17462.678773   0.825004   0.718177
# 68                  0.255290    0.182219  17192.005009   0.823626   0.718383
# 69                  0.254593    0.183642  17436.316844   0.812383   0.707320
#
#                                     result.model_path
# 0   /storage/groups/ml01/workspace/laura.martens/a...
# 1   /storage/groups/ml01/workspace/laura.martens/a...
# 2   /storage/groups/ml01/workspace/laura.martens/a...
# 3   /storage/groups/ml01/workspace/laura.martens/a...
# 4   /storage/groups/ml01/workspace/laura.martens/a...
# ..                                                ...
# 65  /storage/groups/ml01/workspace/laura.martens/a...
# 66  /storage/groups/ml01/workspace/laura.martens/a...
# 67  /storage/groups/ml01/workspace/laura.martens/a...
# 68  /storage/groups/ml01/workspace/laura.martens/a...
# 69  /storage/groups/ml01/workspace/laura.martens/a...
#
# [70 rows x 29 columns]

# %%
df = results[results["config.data.batch"].isna()] #filtering for final run

# %%
df.groupby(['config.data.dataset', 'config.model.model_type', 'config.setup.model_params.n_latent']).size() # check that all have the same number of runs
# Out:
# config.data.dataset   config.model.model_type                config.setup.model_params.n_latent
# Neurips\nall batches  Binary VAE\n(observed seq. coverage)   60                                    5
#                       PeakVI\n(encoded seq. coverage)        80                                    5
#                       Poisson VAE\n(observed seq. coverage)  100                                   5
# Satpathy\net al.      Binary VAE\n(observed seq. coverage)   100                                   5
#                       PeakVI\n(encoded seq. coverage)        70                                    5
#                       Poisson VAE\n(observed seq. coverage)  100                                   5
# dtype: int64

# %% [markdown]
# # Compute mean per model and bring into right format for scib plotting function

# %%
# Export data for scib plotting in R

scib_table = pd.concat(df['result.embedding'].values, axis =1).T
scib_table.index = "/" + df['config.data.dataset'] + "/metrics/unscaled/full_feature/" + df['config.model.model_type'].str.split('\n').str[0] + "_embed"
scib_table.index.name = "X"
scib_table = scib_table.reset_index().groupby('X').agg("mean")

scib_table
# Out:
#                                                     NMI_cluster/label  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.747178
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.750811
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.748451
# /Satpathy\net al./metrics/unscaled/full_feature...           0.820078
# /Satpathy\net al./metrics/unscaled/full_feature...           0.822923
# /Satpathy\net al./metrics/unscaled/full_feature...           0.823789
#
#                                                     ARI_cluster/label  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.659669
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.667789
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.663437
# /Satpathy\net al./metrics/unscaled/full_feature...           0.711561
# /Satpathy\net al./metrics/unscaled/full_feature...           0.713127
# /Satpathy\net al./metrics/unscaled/full_feature...           0.717737
#
#                                                     ASW_label  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...   0.556992
# /Neurips\nall batches/metrics/unscaled/full_fea...   0.546427
# /Neurips\nall batches/metrics/unscaled/full_fea...   0.565146
# /Satpathy\net al./metrics/unscaled/full_feature...   0.564919
# /Satpathy\net al./metrics/unscaled/full_feature...   0.576197
# /Satpathy\net al./metrics/unscaled/full_feature...   0.565167
#
#                                                     ASW_label/batch  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...         0.884315
# /Neurips\nall batches/metrics/unscaled/full_fea...         0.895350
# /Neurips\nall batches/metrics/unscaled/full_fea...         0.880303
# /Satpathy\net al./metrics/unscaled/full_feature...         0.882550
# /Satpathy\net al./metrics/unscaled/full_feature...         0.874271
# /Satpathy\net al./metrics/unscaled/full_feature...         0.885292
#
#                                                     PCR_batch  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...   0.249482
# /Neurips\nall batches/metrics/unscaled/full_fea...   0.026826
# /Neurips\nall batches/metrics/unscaled/full_fea...   0.315351
# /Satpathy\net al./metrics/unscaled/full_feature...   0.224225
# /Satpathy\net al./metrics/unscaled/full_feature...   0.000000
# /Satpathy\net al./metrics/unscaled/full_feature...   0.226731
#
#                                                     cell_cycle_conservation  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...                      NaN
# /Neurips\nall batches/metrics/unscaled/full_fea...                      NaN
# /Neurips\nall batches/metrics/unscaled/full_fea...                      NaN
# /Satpathy\net al./metrics/unscaled/full_feature...                      NaN
# /Satpathy\net al./metrics/unscaled/full_feature...                      NaN
# /Satpathy\net al./metrics/unscaled/full_feature...                      NaN
#
#                                                     isolated_label_F1  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.067199
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.069539
# /Neurips\nall batches/metrics/unscaled/full_fea...           0.070698
# /Satpathy\net al./metrics/unscaled/full_feature...           0.920436
# /Satpathy\net al./metrics/unscaled/full_feature...           0.929212
# /Satpathy\net al./metrics/unscaled/full_feature...           0.921416
#
#                                                     isolated_label_silhouette  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...                   0.511406
# /Neurips\nall batches/metrics/unscaled/full_fea...                   0.483887
# /Neurips\nall batches/metrics/unscaled/full_fea...                   0.514878
# /Satpathy\net al./metrics/unscaled/full_feature...                   0.556249
# /Satpathy\net al./metrics/unscaled/full_feature...                   0.515166
# /Satpathy\net al./metrics/unscaled/full_feature...                   0.554037
#
#                                                     graph_conn  kBET  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...    0.958561   NaN
# /Neurips\nall batches/metrics/unscaled/full_fea...    0.962339   NaN
# /Neurips\nall batches/metrics/unscaled/full_fea...    0.957265   NaN
# /Satpathy\net al./metrics/unscaled/full_feature...    0.990474   NaN
# /Satpathy\net al./metrics/unscaled/full_feature...    0.991217   NaN
# /Satpathy\net al./metrics/unscaled/full_feature...    0.990295   NaN
#
#                                                        iLISI     cLISI  \
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...  0.243119  0.983426
# /Neurips\nall batches/metrics/unscaled/full_fea...  0.236109  0.983271
# /Neurips\nall batches/metrics/unscaled/full_fea...  0.249144  0.984670
# /Satpathy\net al./metrics/unscaled/full_feature...  0.035456  0.996214
# /Satpathy\net al./metrics/unscaled/full_feature...  0.031825  0.997181
# /Satpathy\net al./metrics/unscaled/full_feature...  0.035529  0.996317
#
#                                                     hvg_overlap  trajectory
# X
# /Neurips\nall batches/metrics/unscaled/full_fea...          NaN    0.888515
# /Neurips\nall batches/metrics/unscaled/full_fea...          NaN    0.884897
# /Neurips\nall batches/metrics/unscaled/full_fea...          NaN    0.887515
# /Satpathy\net al./metrics/unscaled/full_feature...          NaN         NaN
# /Satpathy\net al./metrics/unscaled/full_feature...          NaN         NaN
# /Satpathy\net al./metrics/unscaled/full_feature...          NaN         NaN

# %%
scib_table.to_csv(os.path.join(save_path, "integration_metrics_mean.csv"))

# %% [markdown]
# Code to produce plots using the functions from https://github.com/theislab/scib-reproducibility

# %% [markdown]
# ```R
# source("plotSingleTaskATAC.R")
# plotSingleTaskATAC('processed/scib/integration_metrics_mean.csv',
#                   outdir='panels/Figure2/')
# ```

# %%
0
0.750993689361252
0.6510534279997953
0.5686992493461619
0.9001688295599977
0.003441988316334181
""
0.059108006448146164
0.5002428509847194
0.9547859514998105
""
0.21448362523794243
0.9840963806924363
""
0.8900535638468237
